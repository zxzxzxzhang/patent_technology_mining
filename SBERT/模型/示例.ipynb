# %%
from Evolutionary_path_model import Text_cluster
model = Text_cluster(input_file = 'TAC_2020_2023.xlsx', output_file='结果2020_2023.xlsx',model_path='distilbert_model.pth')
cluster_keywords = model.run()
# Out:
# 结束
# 结束
