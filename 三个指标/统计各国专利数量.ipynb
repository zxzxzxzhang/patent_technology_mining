# %%
import pandas as pd

# 假设 df 是你的 DataFrame，column_name 是你要查看的列名
# 例如，如果你要查看名为 'category' 的列每个类别的数量，可以这样写：
df = pd.read_excel('NewNewNew.xlsx')
df
# Out:
#              公开(公告)号             [标]原始申请(专利权)人 原始申请(专利权)人地址   申请日 IPC主分类号  \
# 0       US62875872P0               拜爾拉吉克股份有限公司           US  2019       -
# 1       US62872589P0               拜爾拉吉克股份有限公司           US  2019       -
# 2          US675631A  FARBENFABEN OF ELBERFELD            -  1900    C07C
# 3    US20230250275A1                     ALGIX           US  2023    C08L
# 4    US20230212537A1                   CARBIOS           FR  2022    C12N
# ..               ...                       ...          ...   ...     ...
# 445      EP2294125A2                     罗盖特公司           FR  2009    C08L
# 446      EP2247661A2                     罗盖特公司           FR  2009    C08L
# 447      EP2144221B1                  株式会社LG化学           KR  2009    G09F
# 448      EP2144966A1                   法国阿科玛公司           FR  2008    C08L
# 449      EP1685201A1                     罗盖特公司           FR  2004    C09D
#
#              类别  Year
# 0           未分类     2
# 1           未分类     2
# ...

# %%
counts = df['原始申请(专利权)人地址'].value_counts()

counts
# Out:
# 原始申请(专利权)人地址
# US    81
# FR    72
# CN    44
# DE    42
# KR    31
# CA    21
# BE    18
# NL    17
# IL    16
# GB    16
# JP    16
# TW    15
# FI    14
# IT    11
# CH     6
# SE     3
# BR     3
# LU     3
# NZ     2
# IA     2
# AU     2
# TH     2
# VN     1
# HK     1
# SC     1
# IN     1
# TX     1
# TN     1
# TR     1
# -      1
# ES     1
# PT     1
# DK     1
# SG     1
# Name: count, dtype: int64
